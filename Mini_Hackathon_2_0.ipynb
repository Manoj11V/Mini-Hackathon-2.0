# %% [markdown]
# # Import Dataset

# %%
import pandas as pd
Ev_maker_df=pd.read_csv("/content/drive/MyDrive/Mini-hackathon 2.0/archive/EV Maker by Place.csv")
Op_pc=pd.read_csv("/content/drive/MyDrive/Mini-hackathon 2.0/archive/OperationalPC.csv")
vehicle_class=pd.read_csv("/content/drive/MyDrive/Mini-hackathon 2.0/archive/Vehicle Class - All.csv")
ev_cat=pd.read_csv("/content/drive/MyDrive/Mini-hackathon 2.0/archive/ev_cat_01-24.csv")
ev_sales=pd.read_csv("/content/drive/MyDrive/Mini-hackathon 2.0/archive/ev_sales_by_makers_and_cat_15-24.csv")

# %% [markdown]
# #Checking Null Values

# %%
Ev_maker_df.isnull().sum()
# Out:
# EV Maker    0
# Place       0
# State       0
# dtype: int64

# %%
Op_pc.isnull().sum()
# Out:
# State                     0
# No. of Operational PCS    0
# dtype: int64

# %%
vehicle_class.isnull().sum()
# Out:
# Vehicle Class         0
# Total Registration    0
# dtype: int64

# %%
ev_cat.isnull().sum()
# Out:
# Date                               0
# FOUR WHEELER (INVALID CARRIAGE)    0
# HEAVY GOODS VEHICLE                0
# HEAVY MOTOR VEHICLE                0
# HEAVY PASSENGER VEHICLE            0
# LIGHT GOODS VEHICLE                0
# LIGHT MOTOR VEHICLE                0
# LIGHT PASSENGER VEHICLE            0
# MEDIUM GOODS VEHICLE               0
# MEDIUM PASSENGER VEHICLE           0
# MEDIUM MOTOR VEHICLE               0
# OTHER THAN MENTIONED ABOVE         0
# THREE WHEELER(NT)                  0
# TWO WHEELER (INVALID CARRIAGE)     0
# THREE WHEELER(T)                   0
# TWO WHEELER(NT)                    0
# TWO WHEELER(T)                     0
# dtype: int64

# %%
ev_sales.isnull().sum()
# Out:
# Cat      0
# Maker    0
# 2015     0
# 2016     0
# 2017     0
# 2018     0
# 2019     0
# 2020     0
# 2021     0
# 2022     0
# 2023     0
# 2024     0
# dtype: int64

# %%
print(Ev_maker_df.shape)
print(Op_pc.shape)
print(vehicle_class.shape)
print(ev_cat.shape)
print(ev_sales.shape)
# Out:
# (62, 3)
# (34, 2)
# (16, 2)
# (284, 17)
# (1386, 12)

# %%
print(Ev_maker_df.head(10))
print(Op_pc.head(10))
print(vehicle_class.head(10))
print(ev_cat.head(10))
print(ev_sales.head(10))
# Out:
#               EV Maker        Place        State
# 0          Tata Motors         Pune  Maharashtra
# 1    Mahindra Electric    Bengaluru    Karnataka
# 2         Ather Energy    Bengaluru    Karnataka
# 3        Hero Electric    New Delhi        Delhi
# 4         Ola Electric  Krishnagiri   Tamil Nadu
# 5        Ashok Leyland      Chennai   Tamil Nadu
# 6    TVS Motor Company        Hosur   Tamil Nadu
# 7           Bajaj Auto         Pune  Maharashtra
# 8       MG Motor India        Halol      Gujarat
# 9  Hyundai Motor India      Chennai   Tamil Nadu
#                State  No. of Operational PCS
# 0  Andaman & Nicobar                       3
# 1     Andhra Pradesh                     327
# 2  Arunachal Pradesh                       9
# 3              Assam                      86
# 4              Bihar                     124
# 5         Chandigarh                      12
# 6       Chhattisgarh                     149
# 7        D&D and DNH                       1
# ...

# %%
ev_cat.drop_duplicates(inplace=True)
ev_sales.drop_duplicates(inplace=True)
Ev_maker_df.drop_duplicates(inplace=True)
Op_pc.drop_duplicates(inplace=True)
vehicle_class.drop_duplicates(inplace=True)

# %%
print(Ev_maker_df.shape)
print(Op_pc.shape)
print(vehicle_class.shape)
print(ev_cat.shape)
print(ev_sales.shape)
# Out:
# (61, 3)
# (34, 2)
# (16, 2)
# (284, 17)
# (1386, 12)

# %%
ev_cat['Date'] = pd.to_datetime(ev_cat['Date'], errors='coerce')
ev_cat.head(10)
# Out:
#         Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 0        NaT                                0                    0
# 1 2001-01-01                                0                    1
# 2 2002-01-01                                0                    2
# 3 2003-01-01                                0                    1
# 4 2004-01-01                                0                    2
# 5 2005-01-01                                0                    0
# 6 2006-01-01                                0                    1
# 7 2007-01-01                                0                    3
# 8 2008-01-01                                0                    0
# 9 2009-01-01                                0                    0
#
#    HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 0                    0                        0                    0
# 1                    0                        0                    9
# ...

# %%
ev_cat.dropna(inplace=True)
ev_cat.head(10)
# Out:
#           Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 1   2001-01-01                                0                    1
# 2   2002-01-01                                0                    2
# 3   2003-01-01                                0                    1
# 4   2004-01-01                                0                    2
# 5   2005-01-01                                0                    0
# 6   2006-01-01                                0                    1
# 7   2007-01-01                                0                    3
# 8   2008-01-01                                0                    0
# 9   2009-01-01                                0                    0
# 10  2010-01-01                                0                    0
#
#     HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 1                     0                        0                    9
# ...

# %% [markdown]
# #EV Adoption Trends

# %%
ev_sales.head(10)
# Out:
#    Cat                            Maker  2015  2016  2017  2018  2019  2020  \
# 0   3W      "VOLVO GROUP INDIA PVT LTD"     0     0    31    12     0     0
# 1   3W           3EV INDUSTRIES PVT LTD     0     0     0     0     0     0
# 2   2W           3GB TECHNOLOGY PVT LTD     0     0     0     1     0     0
# 3   3W           3GB TECHNOLOGY PVT LTD     0     1     1     0     0     0
# 4   3W    3S INDUSTRIES PRIVATE LIMITED     0     0     0     0    48    66
# 5  LMV    3S INDUSTRIES PRIVATE LIMITED     0     0     0     0     3     1
# 6   3W  A B EXCAVATORS & EARTHMOVER LTD     0     1     0     0     0     0
# 7   3W                   A D AGRO WORKS     0     0     2     1     0     0
# 8   3W             A K AUTTO ELECTRICAL     0     1    72    56    42     1
# 9   3W                  A K GUPTA & CO.     0     0   100   625   438   195
#
#    2021  2022  2023  2024
# 0     0     0     0     0
# 1   112   390   545    51
# 2     0     0     0     0
# ...

# %%
ev_adoption_trends=ev_sales[["2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"]].sum()
ev_adoption_trends
# Out:
# 2015       7752
# 2016      49249
# 2017      87019
# 2018     129763
# 2019     165786
# 2020     123770
# 2021     328854
# 2022    1020533
# 2023    1529234
# 2024     978943
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(ev_adoption_trends.index,ev_adoption_trends.values)
plt.show()

# %% [markdown]
# #Manufacturer Performance

# %%
ev_sales.head(10)
# Out:
#    Cat                            Maker  2015  2016  2017  2018  2019  2020  \
# 0   3W      "VOLVO GROUP INDIA PVT LTD"     0     0    31    12     0     0
# 1   3W           3EV INDUSTRIES PVT LTD     0     0     0     0     0     0
# 2   2W           3GB TECHNOLOGY PVT LTD     0     0     0     1     0     0
# 3   3W           3GB TECHNOLOGY PVT LTD     0     1     1     0     0     0
# 4   3W    3S INDUSTRIES PRIVATE LIMITED     0     0     0     0    48    66
# 5  LMV    3S INDUSTRIES PRIVATE LIMITED     0     0     0     0     3     1
# 6   3W  A B EXCAVATORS & EARTHMOVER LTD     0     1     0     0     0     0
# 7   3W                   A D AGRO WORKS     0     0     2     1     0     0
# 8   3W             A K AUTTO ELECTRICAL     0     1    72    56    42     1
# 9   3W                  A K GUPTA & CO.     0     0   100   625   438   195
#
#    2021  2022  2023  2024
# 0     0     0     0     0
# 1   112   390   545    51
# 2     0     0     0     0
# ...

# %%
ev_sales['total_sum']=ev_sales.iloc[:,2:].sum(axis=1)
ev_sales.head(10)
# Out:
#    Cat                            Maker  2015  2016  2017  2018  2019  2020  \
# 0   3W      "VOLVO GROUP INDIA PVT LTD"     0     0    31    12     0     0
# 1   3W           3EV INDUSTRIES PVT LTD     0     0     0     0     0     0
# 2   2W           3GB TECHNOLOGY PVT LTD     0     0     0     1     0     0
# 3   3W           3GB TECHNOLOGY PVT LTD     0     1     1     0     0     0
# 4   3W    3S INDUSTRIES PRIVATE LIMITED     0     0     0     0    48    66
# 5  LMV    3S INDUSTRIES PRIVATE LIMITED     0     0     0     0     3     1
# 6   3W  A B EXCAVATORS & EARTHMOVER LTD     0     1     0     0     0     0
# 7   3W                   A D AGRO WORKS     0     0     2     1     0     0
# 8   3W             A K AUTTO ELECTRICAL     0     1    72    56    42     1
# 9   3W                  A K GUPTA & CO.     0     0   100   625   438   195
#
#    2021  2022  2023  2024  total_sum
# 0     0     0     0     0         43
# 1   112   390   545    51       1098
# ...

# %%
ev_sales.sort_values(by="total_sum",ascending=False).head(10)
# Out:
#       Cat                                 Maker  2015  2016  2017   2018  \
# 867    2W     OLA ELECTRIC TECHNOLOGIES PVT LTD     0     0     0      0
# 1230   2W                 TVS MOTOR COMPANY LTD   165   171    69     23
# 118    2W                  ATHER ENERGY PVT LTD     0     0     0     24
# 472    2W       HERO ELECTRIC VEHICLES PVT. LTD     1    34   162   5785
# 864    2W              OKINAWA AUTOTECH PVT LTD     0     1   331   8452
# 148    2W                        BAJAJ AUTO LTD   161    78    43      7
# 1357   3W                   YC ELECTRIC VEHICLE     1  1665  7434  10816
# 76     2W       AMPERE VEHICLES PRIVATE LIMITED     0     0     0      0
# 1020   3W           SAERA ELECTRIC AUTO PVT LTD   140  1203  1532   3226
# 1203  LMV  TATA PASSENGER ELECTRIC MOBILITY LTD     0     0     0      0
#
#        2019  2020   2021    2022    2023    2024  total_sum
# 867       0     0    240  109398  267355  211273     588266
# ...

# %%
ev_cat.head(10)
# Out:
#           Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 1   2001-01-01                                0                    1
# 2   2002-01-01                                0                    2
# 3   2003-01-01                                0                    1
# 4   2004-01-01                                0                    2
# 5   2005-01-01                                0                    0
# 6   2006-01-01                                0                    1
# 7   2007-01-01                                0                    3
# 8   2008-01-01                                0                    0
# 9   2009-01-01                                0                    0
# 10  2010-01-01                                0                    0
#
#     HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 1                     0                        0                    9
# ...

# %%
ev_cat['Total_sum']=ev_cat.iloc[:,1:].sum(axis=1)
ev_cat.head(10).sort_values(by="Total_sum",ascending=False)
# Out:
#           Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 9   2009-01-01                                0                    0
# 8   2008-01-01                                0                    0
# 10  2010-01-01                                0                    0
# 2   2002-01-01                                0                    2
# 7   2007-01-01                                0                    3
# 1   2001-01-01                                0                    1
# 6   2006-01-01                                0                    1
# 3   2003-01-01                                0                    1
# 5   2005-01-01                                0                    0
# 4   2004-01-01                                0                    2
#
#     HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 9                     0                        0                    2
# ...

# %% [markdown]
# #Price vs features

# %% [markdown]
# There is no proper values which represent the price of the electric vehicle and also features like  battery life, range, or charging time

# %% [markdown]
# #Impact of government policies

# %%
import matplotlib.pyplot as plt
plt.bar(ev_adoption_trends.index,ev_adoption_trends.values)
plt.show()

# %% [markdown]
# * Reducing the Goods and Services Tax (GST) on EVs can make them more affordable and increase demand. For example, in India, the GST on EVs was reduced from 12% to 5% in 2019.
# * In India, the Electric Mobility Promotion Scheme (EMPS) 2024 provides incentives of up to Rs 10,000 per electric two-wheeler, and up to Rs 50,000 per electric three-wheeler

# %% [markdown]
# #Geographical Analysis

# %%
ev_maker_by_place = Ev_maker_df['EV Maker'].groupby(Ev_maker_df['State']).size()
ev_maker_by_place.sort_values(ascending=False, inplace=True)
ev_maker_by_place.head(10)
# Out:
# State
# Maharashtra    15
# Tamil Nadu     11
# Haryana         6
# Karnataka       6
# Gujarat         5
# Delhi           4
# Rajasthan       4
# Telangana       3
# West Bengal     3
# Uttarakhand     2
# Name: EV Maker, dtype: int64

# %%
op_pc = Op_pc['No. of Operational PCS'].groupby(Op_pc['State']).sum()
op_pc.sort_values(ascending=False, inplace=True)
op_pc.head(10)
# Out:
# State
# Maharashtra      3079
# Delhi            1886
# Karnataka        1041
# Kerala            852
# Tamil Nadu        643
# Uttar Pradesh     582
# Rajasthan         500
# Telangana         481
# Gujarat           476
# Haryana           377
# Name: No. of Operational PCS, dtype: int64

# %% [markdown]
# #Environmental impact

# %% [markdown]
# Production of electric vehicles increased .so there is reduction of emission of hazard gases to the environment is decreased

# %%
import matplotlib.pyplot as plt
plt.bar(ev_adoption_trends.index,ev_adoption_trends.values)
plt.show()
